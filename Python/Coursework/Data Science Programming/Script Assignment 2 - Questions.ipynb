# %% [markdown]
# # Script Assignment 2 Topics : NumPy & Pandas
# ## COP 4283
# ### Fall 2023

# %% [markdown]
# ### 1. Creating any new DataFrame of size 5 by 5 from the scratch - 1 point

# %%
import pandas as pd
df = pd.DataFrame(columns=[1,2,3,4,5],index=[1,2,3,4,5])
df
# Out:
#      1    2    3    4    5
# 1  NaN  NaN  NaN  NaN  NaN
# 2  NaN  NaN  NaN  NaN  NaN
# 3  NaN  NaN  NaN  NaN  NaN
# 4  NaN  NaN  NaN  NaN  NaN
# 5  NaN  NaN  NaN  NaN  NaN

# %% [markdown]
# ### 2. Reading tabular data (Use: read_csv) - 1 point

# %%
df = pd.read_csv('educ_figdp_1_Data.csv')
df
# Out:
#      TIME                            GEO  \
# 0    2000  European Union (28 countries)
# 1    2001  European Union (28 countries)
# 2    2002  European Union (28 countries)
# 3    2003  European Union (28 countries)
# 4    2004  European Union (28 countries)
# ..    ...                            ...
# 379  2007                        Finland
# 380  2008                        Finland
# 381  2009                        Finland
# 382  2010                        Finland
# 383  2011                        Finland
#
#                                               INDIC_ED Value  \
# 0    Total public expenditure on education as % of ...     :
# 1    Total public expenditure on education as % of ...     :
# 2    Total public expenditure on education as % of ...  5.00
# 3    Total public expenditure on education as % of ...  5.03
# 4    Total public expenditure on education as % of ...  4.95
# ..                                                 ...   ...
# 379  Total public expenditure on education as % of ...  5.90
# 380  Total public expenditure on education as % of ...  6.10
# 381  Total public expenditure on education as % of ...  6.81
# 382  Total public expenditure on education as % of ...  6.85
# 383  Total public expenditure on education as % of ...  6.76
#
#     Flag and Footnotes
# 0                  NaN
# 1                  NaN
# 2                    e
# 3                    e
# 4                    e
# ..                 ...
# 379                NaN
# 380                NaN
# 381                NaN
# 382                NaN
# 383                NaN
#
# [384 rows x 5 columns]

# %% [markdown]
# ### 3. Viewing Data (Use: head, tail, column, index, values, describe) - 1 point

# %%
display(df.head())
display(df.tail())
display(df.columns)
display(df.index)
display(df.values)
display(df.describe())
# Out:
#    TIME                            GEO  \
# 0  2000  European Union (28 countries)
# 1  2001  European Union (28 countries)
# 2  2002  European Union (28 countries)
# 3  2003  European Union (28 countries)
# 4  2004  European Union (28 countries)
#
#                                             INDIC_ED Value Flag and Footnotes
# 0  Total public expenditure on education as % of ...     :                NaN
# 1  Total public expenditure on education as % of ...     :                NaN
# 2  Total public expenditure on education as % of ...  5.00                  e
# 3  Total public expenditure on education as % of ...  5.03                  e
# 4  Total public expenditure on education as % of ...  4.95                  e
#      TIME      GEO                                           INDIC_ED Value  \
# 379  2007  Finland  Total public expenditure on education as % of ...  5.90
# 380  2008  Finland  Total public expenditure on education as % of ...  6.10
# 381  2009  Finland  Total public expenditure on education as % of ...  6.81
# 382  2010  Finland  Total public expenditure on education as % of ...  6.85
# 383  2011  Finland  Total public expenditure on education as % of ...  6.76
#
#     Flag and Footnotes
# 379                NaN
# 380                NaN
# 381                NaN
# 382                NaN
# 383                NaN
# Index(['TIME', 'GEO', 'INDIC_ED', 'Value', 'Flag and Footnotes'], dtype='object')
# RangeIndex(start=0, stop=384, step=1)
# array([[2000, 'European Union (28 countries)',
#         'Total public expenditure on education as % of GDP, for all levels of education combined',
#         ':', nan],
#        [2001, 'European Union (28 countries)',
#         'Total public expenditure on education as % of GDP, for all levels of education combined',
#         ':', nan],
#        [2002, 'European Union (28 countries)',
#         'Total public expenditure on education as % of GDP, for all levels of education combined',
#         '5.00', 'e'],
#        ...,
#        [2009, 'Finland',
#         'Total public expenditure on education as % of GDP, for all levels of education combined',
#         '6.81', nan],
#        [2010, 'Finland',
#         'Total public expenditure on education as % of GDP, for all levels of education combined',
#         '6.85', nan],
#        [2011, 'Finland',
#         'Total public expenditure on education as % of GDP, for all levels of education combined',
#         '6.76', nan]], dtype=object)
#               TIME
# count   384.000000
# mean   2005.500000
# std       3.456556
# min    2000.000000
# 25%    2002.750000
# 50%    2005.500000
# 75%    2008.250000
# max    2011.000000

# %% [markdown]
# ### 4. Selection(Use: Value, select a subset of columns and rows (hint: slice)) - 1 point

# %%
df[['TIME','GEO']].iloc[5:8]
# Out:
#    TIME                            GEO
# 5  2005  European Union (28 countries)
# 6  2006  European Union (28 countries)
# 7  2007  European Union (28 countries)

# %% [markdown]
# ### 5. Filtering Data (Use: any condition (for ex: filter those values less than or equal to 6.5)) - 1 point

# %%
df[df['Value'] == ':'] = 0
df['Value'] = df['Value'].astype(float)
#df.dtypes
df[df['Value'] <= 6.5]
# Out:
#      TIME                            GEO  \
# 0       0                              0
# 1       0                              0
# 2    2002  European Union (28 countries)
# 3    2003  European Union (28 countries)
# 4    2004  European Union (28 countries)
# ..    ...                            ...
# 376  2004                        Finland
# 377  2005                        Finland
# 378  2006                        Finland
# 379  2007                        Finland
# 380  2008                        Finland
#
#                                               INDIC_ED  Value  \
# 0                                                    0   0.00
# 1                                                    0   0.00
# 2    Total public expenditure on education as % of ...   5.00
# 3    Total public expenditure on education as % of ...   5.03
# 4    Total public expenditure on education as % of ...   4.95
# ..                                                 ...    ...
# 376  Total public expenditure on education as % of ...   6.42
# 377  Total public expenditure on education as % of ...   6.30
# 378  Total public expenditure on education as % of ...   6.18
# 379  Total public expenditure on education as % of ...   5.90
# 380  Total public expenditure on education as % of ...   6.10
#
#     Flag and Footnotes
# 0                    0
# 1                    0
# 2                    e
# 3                    e
# 4                    e
# ..                 ...
# 376                NaN
# 377                NaN
# 378                NaN
# 379                NaN
# 380                NaN
#
# [351 rows x 5 columns]

# %% [markdown]
# ### 6. Filtering Missing Values (Use: Nan) - 1 point

# %%
df[df.isna().any(axis=1)]
# Out:
#      TIME       GEO                                           INDIC_ED  Value  \
# 96   2000  Bulgaria  Total public expenditure on education as % of ...   3.88
# 97   2001  Bulgaria  Total public expenditure on education as % of ...   3.70
# 98   2002  Bulgaria  Total public expenditure on education as % of ...   3.94
# 99   2003  Bulgaria  Total public expenditure on education as % of ...   4.09
# 100  2004  Bulgaria  Total public expenditure on education as % of ...   4.40
# ..    ...       ...                                                ...    ...
# 379  2007   Finland  Total public expenditure on education as % of ...   5.90
# 380  2008   Finland  Total public expenditure on education as % of ...   6.10
# 381  2009   Finland  Total public expenditure on education as % of ...   6.81
# 382  2010   Finland  Total public expenditure on education as % of ...   6.85
# 383  2011   Finland  Total public expenditure on education as % of ...   6.76
#
#     Flag and Footnotes
# 96                 NaN
# 97                 NaN
# 98                 NaN
# 99                 NaN
# 100                NaN
# ..                 ...
# 379                NaN
# 380                NaN
# 381                NaN
# 382                NaN
# 383                NaN
#
# [201 rows x 5 columns]

# %% [markdown]
# ### 7. Manipulating Data (Use: drop, append, dropna, fillna) - 1 point

# %%
display(df.drop(['INDIC_ED','Flag and Footnotes'], axis=1))
df2 = pd.DataFrame(index=range(0,351),columns=['A'], dtype='float')
display(df.append(df2))
display(df.dropna())
display(df.fillna(-1))
# Out:
#      TIME                            GEO  Value
# 0       0                              0   0.00
# 1       0                              0   0.00
# 2    2002  European Union (28 countries)   5.00
# 3    2003  European Union (28 countries)   5.03
# 4    2004  European Union (28 countries)   4.95
# ..    ...                            ...    ...
# 379  2007                        Finland   5.90
# 380  2008                        Finland   6.10
# 381  2009                        Finland   6.81
# 382  2010                        Finland   6.85
# 383  2011                        Finland   6.76
#
# [384 rows x 3 columns]
# C:\Users\danma\AppData\Local\Temp\ipykernel_24272\909331615.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   display(df.append(df2))
#        TIME                            GEO  \
# 0       0.0                              0
# 1       0.0                              0
# 2    2002.0  European Union (28 countries)
# 3    2003.0  European Union (28 countries)
# 4    2004.0  European Union (28 countries)
# ..      ...                            ...
# 346     NaN                            NaN
# 347     NaN                            NaN
# 348     NaN                            NaN
# 349     NaN                            NaN
# 350     NaN                            NaN
#
#                                               INDIC_ED  Value  \
# 0                                                    0   0.00
# 1                                                    0   0.00
# 2    Total public expenditure on education as % of ...   5.00
# 3    Total public expenditure on education as % of ...   5.03
# 4    Total public expenditure on education as % of ...   4.95
# ..                                                 ...    ...
# 346                                                NaN    NaN
# 347                                                NaN    NaN
# 348                                                NaN    NaN
# 349                                                NaN    NaN
# 350                                                NaN    NaN
#
#     Flag and Footnotes   A
# 0                    0 NaN
# 1                    0 NaN
# 2                    e NaN
# 3                    e NaN
# 4                    e NaN
# ..                 ...  ..
# 346                NaN NaN
# 347                NaN NaN
# 348                NaN NaN
# 349                NaN NaN
# 350                NaN NaN
#
# [735 rows x 6 columns]
#      TIME                            GEO  \
# 0       0                              0
# 1       0                              0
# 2    2002  European Union (28 countries)
# 3    2003  European Union (28 countries)
# 4    2004  European Union (28 countries)
# ..    ...                            ...
# 367  2007                       Slovakia
# 368  2008                       Slovakia
# 369  2009                       Slovakia
# 370  2010                       Slovakia
# 371  2011                       Slovakia
#
#                                               INDIC_ED  Value  \
# 0                                                    0   0.00
# 1                                                    0   0.00
# 2    Total public expenditure on education as % of ...   5.00
# 3    Total public expenditure on education as % of ...   5.03
# 4    Total public expenditure on education as % of ...   4.95
# ..                                                 ...    ...
# 367  Total public expenditure on education as % of ...   3.62
# 368  Total public expenditure on education as % of ...   3.61
# 369  Total public expenditure on education as % of ...   4.09
# 370  Total public expenditure on education as % of ...   4.22
# 371  Total public expenditure on education as % of ...   4.06
#
#     Flag and Footnotes
# 0                    0
# 1                    0
# 2                    e
# 3                    e
# 4                    e
# ..                 ...
# 367                  d
# 368                  d
# 369                  d
# 370                  d
# 371                  d
#
# [183 rows x 5 columns]
#      TIME                            GEO  \
# 0       0                              0
# 1       0                              0
# 2    2002  European Union (28 countries)
# 3    2003  European Union (28 countries)
# 4    2004  European Union (28 countries)
# ..    ...                            ...
# 379  2007                        Finland
# 380  2008                        Finland
# 381  2009                        Finland
# 382  2010                        Finland
# 383  2011                        Finland
#
#                                               INDIC_ED  Value  \
# 0                                                    0   0.00
# 1                                                    0   0.00
# 2    Total public expenditure on education as % of ...   5.00
# 3    Total public expenditure on education as % of ...   5.03
# 4    Total public expenditure on education as % of ...   4.95
# ..                                                 ...    ...
# 379  Total public expenditure on education as % of ...   5.90
# 380  Total public expenditure on education as % of ...   6.10
# 381  Total public expenditure on education as % of ...   6.81
# 382  Total public expenditure on education as % of ...   6.85
# 383  Total public expenditure on education as % of ...   6.76
#
#     Flag and Footnotes
# 0                    0
# 1                    0
# 2                    e
# 3                    e
# 4                    e
# ..                 ...
# 379                 -1
# 380                 -1
# 381                 -1
# 382                 -1
# 383                 -1
#
# [384 rows x 5 columns]

# %% [markdown]
# ### 8. Sorting (Use: Sort_values, sort_index) - 1 point

# %%
df.sort_values(by='Value')
# Out:
#      TIME      GEO                                           INDIC_ED  Value  \
# 0       0        0                                                  0   0.00
# 36      0        0                                                  0   0.00
# 37      0        0                                                  0   0.00
# 261     0        0                                                  0   0.00
# 342     0        0                                                  0   0.00
# ..    ...      ...                                                ...    ...
# 122  2002  Denmark  Total public expenditure on education as % of ...   8.44
# 121  2001  Denmark  Total public expenditure on education as % of ...   8.44
# 129  2009  Denmark  Total public expenditure on education as % of ...   8.74
# 131  2011  Denmark  Total public expenditure on education as % of ...   8.75
# 130  2010  Denmark  Total public expenditure on education as % of ...   8.81
#
#     Flag and Footnotes
# 0                    0
# 36                   0
# 37                   0
# 261                  0
# 342                  0
# ..                 ...
# 122                  d
# 121                  d
# 129                  d
# 131                  d
# 130                  d
#
# [384 rows x 5 columns]

# %% [markdown]
# ### 9. Grouping Data (Use: Groupby) - 1 point

# %%
df[['GEO','Value']].groupby('GEO').sum(numeric_only=True)
# Out:
#                                                   Value
# GEO
# 0                                                  0.00
# Austria                                           67.42
# Belgium                                           68.08
# Bulgaria                                          49.12
# Cyprus                                            84.28
# Czech Republic                                    50.02
# Denmark                                           99.98
# Estonia                                           63.25
# Euro area (13 countries)                          55.21
# Euro area (15 countries)                          55.28
# Euro area (17 countries)                          49.43
# Euro area (18 countries)                          49.44
# European Union (25 countries)                     61.10
# European Union (27 countries)                     60.73
# European Union (28 countries)                     50.81
# Finland                                           75.92
# France                                            69.57
# Germany (until 1990 former territory of the FRG)  56.22
# Greece                                            22.26
# Hungary                                           62.32
# Ireland                                           60.84
# Italy                                             54.63
# Latvia                                            66.72
# Lithuania                                         63.00
# Luxembourg                                        25.52
# Malta                                             67.10
# Netherlands                                       65.97
# Poland                                            62.37
# Portugal                                          63.57
# Romania                                           34.94
# Slovakia                                          47.96
# Slovenia                                          62.01
# Spain                                             53.57

# %% [markdown]
# ### 10. Rearrange Data(Use: pivot_table, rank) - 1 point

# %%
table = pd.pivot_table(df, values='Value', index=['TIME'], columns=['GEO'], aggfunc="sum")
display(table)
display(df.rank)
# Out:
# GEO     0  Austria  Belgium  Bulgaria  Cyprus  Czech Republic  Denmark  \
# TIME
# 0     0.0      NaN      NaN       NaN     NaN             NaN      NaN
# 2000  NaN     5.66      NaN      3.88    5.42            3.83     8.28
# 2001  NaN     5.74     5.99      3.70    5.98            3.93     8.44
# 2002  NaN     5.68     6.09      3.94    6.60            4.15     8.44
# 2003  NaN     5.53     6.02      4.09    7.37            4.32     8.33
# 2004  NaN     5.48     5.95      4.40    6.77            4.20     8.43
# 2005  NaN     5.44     5.92      4.25    6.95            4.08     8.30
# 2006  NaN     5.40     5.98      4.04    7.02            4.42     7.97
# 2007  NaN     5.33     6.00      3.88    6.95            4.05     7.81
# 2008  NaN     5.47     6.43      4.44    7.45            3.92     7.68
# 2009  NaN     5.98     6.57      4.58    7.98            4.36     8.74
# 2010  NaN     5.91     6.58      4.10    7.92            4.25     8.81
# 2011  NaN     5.80     6.55      3.82    7.87            4.51     8.75
#
# GEO   Estonia  Euro area (13 countries)  Euro area (15 countries)  ...  \
# TIME                                                               ...
# 0         NaN                       NaN                       NaN  ...
# 2000     5.57                       NaN                       NaN  ...
# 2001     5.24                      4.97                      4.98  ...
# 2002     5.47                      5.00                      5.01  ...
# 2003     5.29                      5.04                      5.04  ...
# 2004     4.92                      4.95                      4.96  ...
# 2005     4.88                      4.89                      4.89  ...
# 2006     4.70                      4.87                      4.87  ...
# 2007     4.72                      4.80                      4.81  ...
# 2008     5.61                      4.94                      4.95  ...
# 2009     6.03                      5.32                      5.32  ...
# 2010     5.66                      5.28                      5.29  ...
# 2011     5.16                      5.15                      5.16  ...
#
# GEO   Lithuania  Luxembourg  Malta  Netherlands  Poland  Portugal  Romania  \
# TIME
# 0           NaN         NaN    NaN          NaN     NaN       NaN      NaN
# 2000       5.63         NaN   4.52         4.98    4.87      5.42     2.88
# 2001       5.86        3.75   4.27         5.09    5.42      5.39     3.25
# 2002       5.81        3.79   4.22         5.22    5.41      5.33     3.51
# 2003       5.14        3.77   4.48         5.47    5.35      5.38     3.45
# 2004       5.17        3.87   4.66         5.50    5.41      5.10     3.28
# 2005       4.88        3.78   6.58         5.53    5.47      5.21     3.48
# 2006       4.82        3.41   6.45         5.50    5.25      5.07      NaN
# 2007       4.64        3.15   6.18         5.32    4.91      5.10     4.25
# 2008       4.88         NaN   5.72         5.50    5.08      4.89      NaN
# 2009       5.64         NaN   5.32         5.95    5.09      5.79     4.24
# 2010       5.36         NaN   6.74         5.98    5.17      5.62     3.53
# 2011       5.17         NaN   7.96         5.93    4.94      5.27     3.07
#
# GEO   Slovakia  Slovenia  Spain
# TIME
# 0          NaN       NaN    NaN
# 2000      3.92       NaN   4.28
# 2001      3.99      5.86   4.24
# 2002      4.31      5.76   4.25
# 2003      4.30      5.80   4.28
# 2004      4.19      5.74   4.25
# 2005      3.85      5.73   4.23
# 2006      3.80      5.72   4.26
# 2007      3.62      5.15   4.34
# 2008      3.61      5.20   4.62
# 2009      4.09      5.69   5.02
# 2010      4.22      5.68   4.98
# 2011      4.06      5.68   4.82
#
# [13 rows x 33 columns]
# <bound method NDFrame.rank of      TIME                            GEO  \
# 0       0                              0
# 1       0                              0
# 2    2002  European Union (28 countries)
# 3    2003  European Union (28 countries)
# 4    2004  European Union (28 countries)
# ..    ...                            ...
# 379  2007                        Finland
# 380  2008                        Finland
# 381  2009                        Finland
# 382  2010                        Finland
# 383  2011                        Finland
#
#                                               INDIC_ED  Value  \
# 0                                                    0   0.00
# 1                                                    0   0.00
# 2    Total public expenditure on education as % of ...   5.00
# 3    Total public expenditure on education as % of ...   5.03
# 4    Total public expenditure on education as % of ...   4.95
# ..                                                 ...    ...
# 379  Total public expenditure on education as % of ...   5.90
# 380  Total public expenditure on education as % of ...   6.10
# 381  Total public expenditure on education as % of ...   6.81
# 382  Total public expenditure on education as % of ...   6.85
# 383  Total public expenditure on education as % of ...   6.76
#
#     Flag and Footnotes
# 0                    0
# 1                    0
# 2                    e
# 3                    e
# 4                    e
# ..                 ...
# 379                NaN
# 380                NaN
# 381                NaN
# 382                NaN
# 383                NaN
#
# [384 rows x 5 columns]>

# %% [markdown]
# ### 11. Visualization the data (Use: Stacked bar chart or any of your choice) - Bonus - 5 point

# %%
from matplotlib import pyplot as plt
plot = df[['GEO','Value']].groupby('GEO').sum(numeric_only=True)
plot = plot.iloc[1:]
plt.figure(figsize=(10, 6))  # Adjust the figure size as needed
plt.bar(x=plot.index, height=plot['Value'])
plt.xlabel('GEO')
plt.ylabel('Value')
plt.xticks(rotation=90)  # Rotate x-axis tick labels for better visibility
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()
